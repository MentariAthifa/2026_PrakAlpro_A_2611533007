# %% [markdown]
# <div align="center">
#
# **LAPORAN PRAKTIKUM**
#
# **OPERATOR PYTHON**
#
# **“JUDUL MODUL PRAKTIKUM”**
#
# **Disusun Oleh :**
#
# **Mentari Athifa Khalish Andyni**
#
# **2611533007**
#
# **Dosen Pengampu:**
#
# **Dr. Wahyudi, S.T.M.T**
#
# **Asisten Praktikum:**
#
# **Sherly Sukmadira**
#
# <br>
#
#  <img src="images/logo_unand.png" width="200">
#
# <br>
#
# **FAKULTAS TEKNOLOGI INFORMASI**
#
# **DEPARTEMEN INFORMATIKA**
#
# **UNIVERSITAS ANDALAS**
#
# **2026**
#
# </div>

# %% [markdown]
# ## <h1 align="center"> KATA PENGANTAR <h1>
#
# Puji syukur penulis panjatkan atas kehadirat Tuhan Yang Maha Esa yang telah memberikan rahmat dan berkat-Nya, sehingga penulis dapat menyelesaikan laporan praktikum Operator Python yang telah dilaksanakan sebagai pertemuan ke-3 untuk mata kuliah Praktikum Algoritma Pemrogaman. Praktikum ini berfokus pada pembahasan berbagai jenis operator dalam Python, yaitu operator aritmatika, bitwise, assignment, logika, perbandingan, dan operator lainnya, serta penerapannya dalam pembuatan program.
#
# Melalui praktikum ini, hasil yang diharapkan adalah penulis dapat memahami dan mengimplementasikan secara langsung konsep operator Python dalam melakukan operasi perhitungan, perbandingan, logika, pemberian nilai, serta pengolahan data pada real project.
#
# Penulis menyadari bahwa laporan praktikum ini masih memiliki banyak kekurangan. Oleh karena itu, kritik dan saran yang membangun sangat diharapkan demi perbaikan dan pengembangan di masa mendatang.
#
# <h5 align="right" style="margin-right:30px;">Padang, 2026
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# Mentari Athifa Khalish Andyni<br>
# 2611533007
# </h5>

# %% [markdown]
# ---
# # BAB I
# # PENDAHULUAN
#
# ## 1.1 Latar Belakang
# Tuliskan latar belakang topik praktikum di sini: mengapa konsep ini penting dipelajari, konteks penggunaannya dalam pemrograman, dsb.
#
# ## 1.2 Tujuan
# 1. Tujuan pertama.
# 2. Tujuan kedua.
# 3. Tujuan ketiga.
#
# ## 1.3 Manfaat
# 1. Manfaat pertama.
# 2. Manfaat kedua.

# %% [markdown]
# ---
# # BAB II
# # PEMBAHASAN
#
# ## 2.1 Dasar Teori
# ### 2.1.1 Python
# Python merupakan salah satu bahasa pemrograman tingkat tinggi yang memiliki sintaks sederhana dan mudah dipahami. Python banyak digunakan dalam berbagai bidang, seperti pengembangan perangkat lunak, pengolahan data, dan pembelajaran pemrograman. Karena sintaksnya relatif sederhana, Python juga sesuai digunakan untuk mempelajari konsep dasar pemrograman.
#
# Dalam Python terdapat berbagai sintaks dasar, seperti fungsi print() yang digunakan untuk menampilkan informasi ke layar dan komentar yang digunakan untuk memberikan keterangan pada kode program. Python juga menggunakan string untuk menyimpan atau menampilkan data berupa teks. Beberapa string dapat digabungkan menggunakan operator +. Selain itu, Python memiliki escape character, seperti \\, yang dapat digunakan untuk menghasilkan karakter atau format tertentu dalam output.
#
# ### 2.1.2

# %% [markdown]
# ## 2.2 Kode Program
#
# ### 2.2.1 Program "NamaKelas_NIM"
# Jalankan sel kode di bawah ini agar Jupyter otomatis menyimpan kodenya beserta outputnya sebagai satu kesatuan (tidak perlu screenshot terpisah untuk hasil run).

# %%
# Tulis/tempel kode program di sini.
# Catatan: jika bahasa aslinya Java/C/dst, kode tetap bisa ditulis apa adanya
# di dalam sel ini sebagai referensi teks (tidak harus dieksekusi di Python),
# atau gunakan magic %%writefile untuk menuliskannya ke file .java lalu
# dijalankan lewat perintah shell (lihat file tutorial terpisah).

# %% [markdown]
# **Penjelasan :**
# 1. Bagian pertama kode ini berfungsi untuk ...
# 2. Bagian kedua berfungsi untuk ...
# 3. Bagian ketiga berfungsi untuk ...

# %% [markdown]
# ### 2.2.2 Program Driver "NamaDriver_NIM"

# %%
# Tulis/tempel kode program driver di sini

# %% [markdown]
# Penjelasan program driver di atas: ...
#
# Jika hasil run program didapat dari IDE/terminal lain (bukan dari cell notebook ini), masukkan tangkapan layarnya seperti berikut (atur ukuran & posisi tengah):
#
# <div align="center">
# <img src="images/output1.png" width="400"><br>
# <em>Gambar 2.1 : Output Program</em>
# </div>

# %% [markdown]
# ---
# ## Tugas Praktikum
#
# **Soal :**
#
# <div align="center">
# <img src="images/soal_tugas.png" width="500"><br>
# <em>Gambar 2.2 : Soal Tugas Praktikum</em>
# </div>

# %% [markdown]
# **Kode Jawaban :**
#
# a. Kode Program "NamaKelas_NIM"

# %%
# Kode jawaban tugas bagian a

# %% [markdown]
# b. Kode Program Driver "NamaDriver_NIM"

# %%
# Kode jawaban tugas bagian b (driver)

# %% [markdown]
# **Output :**
#
# <div align="center">
# <img src="images/output_tugas.png" width="400"><br>
# <em>Gambar 2.3 : Output Tugas Praktikum</em>
# </div>
#
# **Penjelasan :** Program tugas ini ...

# %% [markdown]
# ---
# # BAB III
# # KESIMPULAN
#
# Berdasarkan praktikum yang telah dilakukan, dapat disimpulkan bahwa ...
#
# Dalam konteks pemrograman ..., konsep ini memanfaatkan ... sehingga ...

# %% [markdown]
# ---
# ## DAFTAR PUSTAKA
#
# [1] Penulis, "Judul Referensi," Nama Situs/Jurnal, [Tahun]. [Online]. Tersedia: https://... [Diakses tanggal].
#
# [2] Penulis, "Judul Buku/Diktat," [Tahun], Hal. ...
